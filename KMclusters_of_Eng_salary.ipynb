# %% [markdown]
# # ***Engineers Salary***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/earning.csv') # HERE THESE ALL THE DATA ARE GETTING MESS///
df.head()
# Out:
#   year;females;femalesmanagers;femaleprofessionals;femaletechniciansandtradesworkers;femalecommunityandpersonalserviceworkers;femaleclericalandadministrativeworkers;femalesalesworkers;femalemachineryoperatorsanddrivers;femalelabourers;males;malemanagers;maleprofessionals;maletechniciansandtradesworkers;malecommunityandpersonalserviceworkers;maleclericalandadministrativeworkers;malesalesworkers;malemachineryoperatorsanddrivers;malelabourers;persons;personmanagers;personprofessionals;persontechniciansandtradesworkers;personcommunityandpersonalserviceworkers;personclericalandadministrativeworkers;personsalesworkers;personmachineryoperatorsanddrivers;personlabourers
# 0  2004;Females;26.14;29.02;17.9;18.01;19.98;14.7...
# 1  2005;Females;28.1;30;18.86;18.2;20.95;15.39;21...
# 2  2006;Females;28.6;30.56;19.64;18.84;21.73;16.1...
# 3  2007;Females;36.43;31.93;20.98;19.85;23.27;16....
# 4  2008;Females;32.68;32.93;20.3;20.97;23.67;17.4...

# %% [markdown]
# TO EQUIP ALL THE DATAFRAME, WE USED **';'** TO SPLIT ALL THE GATHERINGS///

# %%
#TO SPLIT ALL THE DATAFRAMES,,,,,,,
df=pd.read_csv('/content/earning.csv', ';')
df.head()
# Out:
# <ipython-input-336-01820844725f>:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df=pd.read_csv('/content/earning.csv', ';')
#    year  females  femalesmanagers  femaleprofessionals  \
# 0  2004  Females            26.14                29.02
# 1  2005  Females            28.10                30.00
# 2  2006  Females            28.60                30.56
# 3  2007  Females            36.43                31.93
# 4  2008  Females            32.68                32.93
#
#    femaletechniciansandtradesworkers  \
# 0                              17.90
# 1                              18.86
# 2                              19.64
# 3                              20.98
# 4                              20.30
#
#    femalecommunityandpersonalserviceworkers  \
# 0                                     18.01
# 1                                     18.20
# 2                                     18.84
# ...

# %%
df=df.drop("year",axis=1)
df.head()
# Out:
#    females  femalesmanagers  femaleprofessionals  \
# 0  Females            26.14                29.02
# 1  Females            28.10                30.00
# 2  Females            28.60                30.56
# 3  Females            36.43                31.93
# 4  Females            32.68                32.93
#
#    femaletechniciansandtradesworkers  \
# 0                              17.90
# 1                              18.86
# 2                              19.64
# 3                              20.98
# 4                              20.30
#
#    femalecommunityandpersonalserviceworkers  \
# 0                                     18.01
# 1                                     18.20
# 2                                     18.84
# 3                                     19.85
# 4                                     20.97
#
#    femaleclericalandadministrativeworkers  femalesalesworkers  \
# 0                                   19.98               14.79
# ...

# %%
df=df.drop("females",axis=1)
df.head()
# Out:
#    femalesmanagers  femaleprofessionals  femaletechniciansandtradesworkers  \
# 0            26.14                29.02                              17.90
# 1            28.10                30.00                              18.86
# 2            28.60                30.56                              19.64
# 3            36.43                31.93                              20.98
# 4            32.68                32.93                              20.30
#
#    femalecommunityandpersonalserviceworkers  \
# 0                                     18.01
# 1                                     18.20
# 2                                     18.84
# 3                                     19.85
# 4                                     20.97
#
#    femaleclericalandadministrativeworkers  femalesalesworkers  \
# 0                                   19.98               14.79
# 1                                   20.95               15.39
# ...

# %%
df=df.drop('persons',axis=1)
df.head()
# Out:
#    femalesmanagers  femaleprofessionals  femaletechniciansandtradesworkers  \
# 0            26.14                29.02                              17.90
# 1            28.10                30.00                              18.86
# 2            28.60                30.56                              19.64
# 3            36.43                31.93                              20.98
# 4            32.68                32.93                              20.30
#
#    femalecommunityandpersonalserviceworkers  \
# 0                                     18.01
# 1                                     18.20
# 2                                     18.84
# 3                                     19.85
# 4                                     20.97
#
#    femaleclericalandadministrativeworkers  femalesalesworkers  \
# 0                                   19.98               14.79
# 1                                   20.95               15.39
# ...

# %%
df=df.drop("males",axis=1)
df.head()
# Out:
#    femalesmanagers  femaleprofessionals  femaletechniciansandtradesworkers  \
# 0            26.14                29.02                              17.90
# 1            28.10                30.00                              18.86
# 2            28.60                30.56                              19.64
# 3            36.43                31.93                              20.98
# 4            32.68                32.93                              20.30
#
#    femalecommunityandpersonalserviceworkers  \
# 0                                     18.01
# 1                                     18.20
# 2                                     18.84
# 3                                     19.85
# 4                                     20.97
#
#    femaleclericalandadministrativeworkers  femalesalesworkers  \
# 0                                   19.98               14.79
# 1                                   20.95               15.39
# ...

# %%
#Renaming////
df=df.rename(columns={'femalesmanagers':'fm','femaleprofessionals':'fp','femaletechniciansandtradesworkers':'ftstw','femalecommunityandpersonalserviceworkers':'fcapsw','femaleclericalandadministrativeworkers':'feaaw','femalesalesworkers':'fw','femalemachineryoperatorsanddrivers':'fmoar','femalelabourers':"fl","malemanagers":'mm','maleprofessionals':'mp','malemachineryoperatorsanddrivers':'mmoar','malelabourers':'ml','personmanagers':'pm','personprofessionals':'pp','persontechniciansandtradesworkers':'ptatw','personcommunityandpersonalserviceworkers':'pcapsw','personclericalandadministrativeworkers':'pcleraaw','personsalesworkers':'pw','personmachineryoperatorsanddrivers':'pmoad','personlabourers':'pl'})
df.head()
# Out:
#       fm     fp  ftstw  fcapsw  feaaw     fw  fmoar     fl     mm     mp  ...  \
# 0  26.14  29.02  17.90   18.01  19.98  14.79  16.27  16.48  33.02  34.03  ...
# 1  28.10  30.00  18.86   18.20  20.95  15.39  21.49  16.71  33.13  34.20  ...
# 2  28.60  30.56  19.64   18.84  21.73  16.19  17.37  16.32  35.16  34.34  ...
# 3  36.43  31.93  20.98   19.85  23.27  16.78  18.04  17.54  38.85  38.85  ...
# 4  32.68  32.93  20.30   20.97  23.67  17.44  20.27  17.27  38.34  39.40  ...
#
#    mmoar     ml     pm     pp  ptatw  pcapsw  pcleraaw     pw  pmoad     pl
# 0  20.92  17.21  30.60  31.22  21.58   19.03     20.80  16.13  20.39  16.95
# 1  21.04  17.85  31.37  31.91  21.42   19.60     21.71  16.70  21.09  17.44
# 2  21.36  18.18  32.82  32.28  22.18   20.04     22.82  17.57  21.00  17.48
# 3  23.06  19.68  37.95  35.01  23.52   21.32     24.61  18.28  22.55  18.88
# 4  23.70  19.79  36.24  35.84  24.19   24.25     24.76  19.34  23.33  18.85
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (14, 24)

# %%
df.describe()
# Out:
#               fm         fp      ftstw     fcapsw      feaaw         fw  \
# count  14.000000  14.000000  14.000000  14.000000  14.000000  14.000000
# mean   35.964286  37.065714  22.979286  22.597857  26.558571  19.630714
# std     6.134298   6.119284   3.488287   3.277464   4.516377   3.383354
# min    26.140000  29.020000  17.900000  18.010000  19.980000  14.790000
# 25%    32.835000  32.180000  20.217500  20.130000  23.370000  16.945000
# 50%    35.730000  36.000000  23.025000  22.610000  26.295000  19.510000
# 75%    40.905000  42.835000  25.697500  24.882500  30.735000  22.112500
# max    46.020000  47.040000  28.300000  27.840000  33.540000  26.110000
#
#            fmoar         fl         mm         mp  ...      mmoar         ml  \
# count  14.000000  14.000000  14.000000  14.000000  ...  14.000000  14.000000
# mean   23.685000  19.953571  42.518571  43.027143  ...  26.629286  21.987143
# std     5.075312   3.054882   6.324777   6.511193  ...   4.064915   3.258960
# ...

# %% [markdown]
# **# For the visualization of engineers wages,, we have to pick 2 several elements amongst them.. **

# %%
plt.scatter(df.fm, df.mm,color='tan')
plt.xlabel('Females managers')
plt.ylabel('Male managers')
plt.title('Salary plot 1')
# Out:
# Text(0.5, 1.0, 'Salary plot 1')

# %%
plt.scatter(df.fmoar, df.mmoar,color='teal')
plt.xlabel('Female machinery operators and drivers')
plt.ylabel('Male machinery operators and drivers')
plt.title('Salary plot 2')
# Out:
# Text(0.5, 1.0, 'Salary plot 2')

# %%
plt.scatter(df.fl, df.pl,color='skyblue')
plt.xlabel('Female labourers')
plt.ylabel('Malel elabourers')
plt.title('Salary plot 3')
# Out:
# Text(0.5, 1.0, 'Salary plot 3')

# %% [markdown]
# ### Pairplot of all females salary.

# %%
sns.pairplot(df[['fm',"fp",'ftstw','fcapsw','feaaw','fw','fmoar',	'fl']])

# %% [markdown]
# Pairplot of all males salary.

# %%
sns.pairplot(df[['mm','mp','mmoar','ml']])

# %% [markdown]
# Salary of all the personal staffs//

# %%
sns.pairplot(df[['pm','pp','ptatw','pcapsw','pcleraaw','pw','pmoad','pl']])

# %%
#After analyzing the salary of all the staffs data, we proceed to the K-means clustering//
from sklearn.cluster import KMeans

# %%
km=KMeans(n_clusters=8) #Creating K-means object wit eight iterations...

# %%
km.fit(df[['fm',"fp",'ftstw','fcapsw','feaaw','fw','fmoar','fl']]) #fit( )--> training the ml model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans()

# %%
KMeans()
# Out:
# KMeans()

# %%
df.head()
# Out:
#       fm     fp  ftstw  fcapsw  feaaw     fw  fmoar     fl     mm     mp  ...  \
# 0  26.14  29.02  17.90   18.01  19.98  14.79  16.27  16.48  33.02  34.03  ...
# 1  28.10  30.00  18.86   18.20  20.95  15.39  21.49  16.71  33.13  34.20  ...
# 2  28.60  30.56  19.64   18.84  21.73  16.19  17.37  16.32  35.16  34.34  ...
# 3  36.43  31.93  20.98   19.85  23.27  16.78  18.04  17.54  38.85  38.85  ...
# 4  32.68  32.93  20.30   20.97  23.67  17.44  20.27  17.27  38.34  39.40  ...
#
#    mmoar     ml     pm     pp  ptatw  pcapsw  pcleraaw     pw  pmoad     pl
# 0  20.92  17.21  30.60  31.22  21.58   19.03     20.80  16.13  20.39  16.95
# 1  21.04  17.85  31.37  31.91  21.42   19.60     21.71  16.70  21.09  17.44
# 2  21.36  18.18  32.82  32.28  22.18   20.04     22.82  17.57  21.00  17.48
# 3  23.06  19.68  37.95  35.01  23.52   21.32     24.61  18.28  22.55  18.88
# 4  23.70  19.79  36.24  35.84  24.19   24.25     24.76  19.34  23.33  18.85
#
# [5 rows x 24 columns]

# %%
#For the female's salary manipulation,
#'fm',"fp",'ftstw','fcapsw','feaaw','fw','fmoar','fl'
km.predict(df[['fm',"fp",'ftstw','fcapsw','feaaw','fw','fmoar','fl']])
# Out:
# array([3, 7, 3, 1, 6, 6, 4, 4, 0, 0, 2, 2, 2, 5], dtype=int32)

# %%
df['NewCluster1']=km.predict(df[['fm',"fp",'ftstw','fcapsw','feaaw','fw','fmoar','fl']])#

# %%
df.head()
# Out:
#       fm     fp  ftstw  fcapsw  feaaw     fw  fmoar     fl     mm     mp  ...  \
# 0  26.14  29.02  17.90   18.01  19.98  14.79  16.27  16.48  33.02  34.03  ...
# 1  28.10  30.00  18.86   18.20  20.95  15.39  21.49  16.71  33.13  34.20  ...
# 2  28.60  30.56  19.64   18.84  21.73  16.19  17.37  16.32  35.16  34.34  ...
# 3  36.43  31.93  20.98   19.85  23.27  16.78  18.04  17.54  38.85  38.85  ...
# 4  32.68  32.93  20.30   20.97  23.67  17.44  20.27  17.27  38.34  39.40  ...
#
#       ml     pm     pp  ptatw  pcapsw  pcleraaw     pw  pmoad     pl  \
# 0  17.21  30.60  31.22  21.58   19.03     20.80  16.13  20.39  16.95
# 1  17.85  31.37  31.91  21.42   19.60     21.71  16.70  21.09  17.44
# 2  18.18  32.82  32.28  22.18   20.04     22.82  17.57  21.00  17.48
# 3  19.68  37.95  35.01  23.52   21.32     24.61  18.28  22.55  18.88
# 4  19.79  36.24  35.84  24.19   24.25     24.76  19.34  23.33  18.85
#
#    NewCluster1
# 0            3
# 1            7
# 2            3
# ...

# %% [markdown]
# VISUALIZATION OF THE NEW CLUSTERING DATA//

# %% [markdown]
# Here we visualize a couple of features likely to 'Female machinery operators and drivers ' and ' Female technician sand-trades workers'by using elbow method.

# %%
df3=df[df.NewCluster1 == 3]
df3.head()
# Out:
#       fm     fp  ftstw  fcapsw  feaaw     fw  fmoar     fl     mm     mp  ...  \
# 0  26.14  29.02  17.90   18.01  19.98  14.79  16.27  16.48  33.02  34.03  ...
# 2  28.60  30.56  19.64   18.84  21.73  16.19  17.37  16.32  35.16  34.34  ...
#
#       ml     pm     pp  ptatw  pcapsw  pcleraaw     pw  pmoad     pl  \
# 0  17.21  30.60  31.22  21.58   19.03     20.80  16.13  20.39  16.95
# 2  18.18  32.82  32.28  22.18   20.04     22.82  17.57  21.00  17.48
#
#    NewCluster1
# 0            3
# 2            3
#
# [2 rows x 25 columns]

# %%
df3.shape
# Out:
# (2, 25)

# %%
plt.scatter(df3.fmoar, df3.ftstw, color='magenta')
plt.xlabel('Female machinery operators and drivers')
plt.ylabel('Female technician sand-trades workers')
plt.title('Salary plot 4')
# Out:
# Text(0.5, 1.0, 'Salary plot 4')

# %%
#For the 8th no of iterations, we analyze here df 0-7.
df0=df[df.NewCluster1 == 0]
df1=df[df.NewCluster1 == 1]
df2=df[df.NewCluster1 == 2]
df3=df[df.NewCluster1 == 3]
df4=df[df.NewCluster1 == 4]
df5=df[df.NewCluster1 == 5]
df6=df[df.NewCluster1 == 6]
df7=df[df.NewCluster1 == 7]

plt.figure(figsize=(8,6))

plt.scatter(df0.fmoar, df0.ftstw, color='black', label='Cluster 0')
plt.scatter(df1.fmoar, df1.ftstw, color='yellow', label='Cluster 1')
plt.scatter(df2.fmoar, df2.ftstw, color='aqua', label='Cluster 2')
plt.scatter(df3.fmoar, df3.ftstw, color='magenta', label='Cluster 3')
plt.scatter(df4.fmoar, df4.ftstw, color='pink', label='Cluster 4')
plt.scatter(df5.fmoar, df5.ftstw, color='blue', label='Cluster 5')
plt.scatter(df6.fmoar, df6.ftstw, color='cyan', label='Cluster 6')
plt.scatter(df7.fmoar, df7.ftstw, color='red', label='Cluster 7')

plt.xlabel('Female machinery operators and drivers')
plt.ylabel('Female technician sand-trades workers')
plt.title('Salary plot 5')

plt.legend()
plt.show()

# %%
centrer1=km.cluster_centers_ #To define the centroids(centres) of each clusters//
centrer1
# Out:
# array([[36.75      , 38.335     , 23.925     , 24.01      , 28.365     ,
#         21.215     , 24.74      , 21.37      ],
#        [36.43      , 31.93      , 20.98      , 19.85      , 23.27      ,
#         16.78      , 18.04      , 17.54      ],
#        [43.03333333, 44.68333333, 27.21333333, 26.14      , 31.85      ,
#         22.88666667, 30.49333333, 23.49666667],
#        [27.37      , 29.79      , 18.77      , 18.425     , 20.855     ,
#         15.49      , 16.82      , 16.4       ],
#        [34.815     , 36.        , 23.025     , 22.61      , 26.295     ,
#         19.51      , 22.83      , 19.5       ],
#        [46.02      , 47.04      , 28.3       , 27.84      , 33.54      ,
#         26.11      , 30.07      , 24.9       ],
#        [32.99      , 33.825     , 20.245     , 20.985     , 23.74      ,
#         17.73      , 20.865     , 17.585     ],
#        [28.1       , 30.        , 18.86      , 18.2       , 20.95      ,
# ...

# %%
df0=df[df.NewCluster1 == 0]
df1=df[df.NewCluster1 == 1]
df2=df[df.NewCluster1 == 2]
df3=df[df.NewCluster1 == 3]
df4=df[df.NewCluster1 == 4]
df5=df[df.NewCluster1 == 5]
df6=df[df.NewCluster1 == 6]
df7=df[df.NewCluster1 == 7]

plt.figure(figsize=(8,6))

plt.scatter(df0.fmoar, df0.ftstw, color='black', label='Cluster 0')
plt.scatter(df1.fmoar, df1.ftstw, color='yellow', label='Cluster 1')
plt.scatter(df2.fmoar, df2.ftstw, color='aqua', label='Cluster 2')
plt.scatter(df3.fmoar, df3.ftstw, color='magenta', label='Cluster 3')
plt.scatter(df4.fmoar, df4.ftstw, color='pink', label='Cluster 4')
plt.scatter(df5.fmoar, df5.ftstw, color='blue', label='Cluster 5')
plt.scatter(df6.fmoar, df6.ftstw, color='cyan', label='Cluster 6')
plt.scatter(df7.fmoar, df7.ftstw, color='tan', label='Cluster 7')

plt.scatter(centrer1[:,0], centrer1[:,1], color='red', marker='*')

plt.xlabel('Female machinery operators and drivers')
plt.ylabel('Female technician sand-trades workers')
plt.title('Salary plot 5')

plt.legend()
plt.show()

# %%
#To optimize the K-means//,,
km=KMeans(n_clusters=8)

wcss=[]
ClustersRange= range(1,10)
for k in ClustersRange:
  km2=KMeans(n_clusters=k)
  km2.fit(df[['fmoar','ftstw']])
  wcss.append(km2.inertia_) #To add the updated value of each iteration.
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [493.05024285714285,
#  127.79042499999998,
#  41.02532500000001,
#  18.71524166666667,
#  13.470358333333332,
#  9.012258333333333,
#  5.921283333333333,
#  3.727533333333336,
#  2.1883000000000012]

# %%
plt.plot( ClustersRange, wcss, marker='+')
plt.xlabel('Clusters')
# Out:
# Text(0.5, 0, 'Clusters')

# %%
# !pip install kneed

# %%
from kneed import KneeLocator #Applying elbow method//
kn = KneeLocator(clusters_range, wcss, curve='convex', direction='decreasing')

# %%
kn.plot_knee()

# %%
kn.knee #To Find out the optimal number of clusters.
# Out:
# 3

# %% [markdown]
# So, here the resultant number 3 is optimal number of these clusters.

# %%
KMeans(n_clusters=3)
# Out:
# KMeans(n_clusters=3)

# %%
#Executing new optimal number of
km3=KMeans(n_clusters=3) #Again creating K-means object with number of clusters, K=3.
km3.fit(df[['fmoar','ftstw']]) #---> Again Training the ML model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
df['OC']= km3.predict(df[['fmoar','ftstw']]) #Renaming the optimized clusters as OC\\\\
df.head()
# Out:
#       fm     fp  ftstw  fcapsw  feaaw     fw  fmoar     fl     mm     mp  ...  \
# 0  26.14  29.02  17.90   18.01  19.98  14.79  16.27  16.48  33.02  34.03  ...
# 1  28.10  30.00  18.86   18.20  20.95  15.39  21.49  16.71  33.13  34.20  ...
# 2  28.60  30.56  19.64   18.84  21.73  16.19  17.37  16.32  35.16  34.34  ...
# 3  36.43  31.93  20.98   19.85  23.27  16.78  18.04  17.54  38.85  38.85  ...
# 4  32.68  32.93  20.30   20.97  23.67  17.44  20.27  17.27  38.34  39.40  ...
#
#       pm     pp  ptatw  pcapsw  pcleraaw     pw  pmoad     pl  NewCluster1  OC
# 0  30.60  31.22  21.58   19.03     20.80  16.13  20.39  16.95            3   2
# 1  31.37  31.91  21.42   19.60     21.71  16.70  21.09  17.44            7   2
# 2  32.82  32.28  22.18   20.04     22.82  17.57  21.00  17.48            3   2
# 3  37.95  35.01  23.52   21.32     24.61  18.28  22.55  18.88            1   2
# 4  36.24  35.84  24.19   24.25     24.76  19.34  23.33  18.85            6   2
#
# [5 rows x 26 columns]

# %%
centrer2=km3.cluster_centers_ #Again define the centroids(centres) of each optimized clusters//
centrer2
# Out:
# array([[23.785 , 23.475 ],
#        [30.3875, 27.485 ],
#        [19.15  , 19.645 ]])

# %%
df0=df[df.OC == 0]
df1=df[df.OC == 1]
df2=df[df.OC == 2]

plt.figure(figsize=(8,6))

plt.scatter(df0.fmoar, df0.ftstw, color='blue', label='Cluster 0')
plt.scatter(df1.fmoar, df1.ftstw, color='yellow', label='Cluster 1')
plt.scatter(df2.fmoar, df2.ftstw, color='aqua', label='Cluster 2')

plt.scatter(centrer2[:,0], centrer2[:,1], color='red', marker='*')

plt.xlabel('Female machinery operators and drivers')
plt.ylabel('Female technician sand-trades workers')
plt.title('The resultant salary plot 6')

plt.legend()
plt.show()
